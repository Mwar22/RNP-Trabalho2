# %% [markdown]
# # Trabalho 2
# ### by Lucas de Jesus B. Gonçalves

# %%
import torch
import torch.functional as F
import torch.nn.init as init
import numpy as np
import matplotlib.pyplot as plt
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchsummary import summary

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 2060 SUPER'

# %% [markdown]
# ### Dataset

# %%
# gera os dados segundo o trabalho
def datagen(qtd_amostras = 500):
    #parâmetros de inicialização
    beta, gamma = 0.4, 0.2 #Não mudar
    n, tau = 18, 20 #Não mudar
    
    x = tau*[0]
    x.append(1)
    for _ in range(0,qtd_amostras):
        xt = x[-1]+(beta*x[-tau]/(1+x[-tau]**n))-gamma*x[-1]
        x.append(xt)
        
    return x[tau+1:]
    
class TSDataset(Dataset):
    def __init__(self, data, step_ahead):
        self.step_ahead = step_ahead
        self.data=torch.tensor(data, dtype=torch.float32)

    #------------metodos sobrecarregados de Dataset-----------------
    def __getitem__(self, index):
        x = self.data[index: index + self.step_ahead]
        y = self.data[index + step_ahead]
        return x, y
        
    def __len__(self):
        return len(self.data) - self.step_ahead

# %% [markdown]
# ### Modelo

# %%
class MeuModelo(nn.Module):
    def __init__(self, step_ahead):
        
        #chama o construtor da superclasse
        super().__init__()

        drate = 0.05

        self.layer0 = nn.Sequential(
            nn.Linear(step_ahead, 64), 
            nn.BatchNorm1d(64),
            nn.LeakyReLU(negative_slope=0.01),
            nn.Dropout(drate),
        )

        self.layer1 = nn.Sequential(
            nn.Linear(64, 64), 
            nn.BatchNorm1d(64),
            nn.LeakyReLU(negative_slope=0.01),
            nn.Dropout(drate/2),
        )
        self.layer2 = nn.Sequential(
            nn.Linear(64, 32), 
            nn.BatchNorm1d(32),
            nn.LeakyReLU(negative_slope=0.01),
            nn.Dropout(drate/4),
        )
        
        self.out =  nn.Linear(32, 1)
    

        #chama função de inicialização dos pesos
        self.init_weights()

    
    def forward(self, x):
        
        x = self.layer0(x)
        x = self.layer1(x)
        x = self.layer2(x)
        x = self.out(x)
      
        return x

    
    
    #inicializa pesos com inicialização kaiming (melhor q xavier para relu)
    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                init.kaiming_normal_(m.weight, a= 0.01, nonlinearity='leaky_relu') #para evitar problemas com relu
                if m.bias is not None:
                    init.constant_(m.bias, 0)

    

    def treinar(self, train_loader, val_loader, num_epochs, cost_function, optimizer, scheduler = None, verbose=True):
        
        # Dispositivo para o processamento
        device = next(self.parameters()).device

        #ativa o autotuner do cuDNN = + performace
        torch.backends.cudnn.benchmark = True

        #ativa scaler para quando o gradiente é muito pequeno quando usando fp16
        scaler = torch.cuda.amp.GradScaler()

        #otimização gpu
        use_amp = True
        #-----------------------------------------------------------------------
    
        
        loss_history = {"train": [], "val":[]}
        learning_rates = []

        for epoch in range(num_epochs):
    
            # Loss acumulada para o treino
            acum_train_loss = 0
            acum_val_loss = 0

            #define como treino
            self.train()
            
            # loop para cada batch
            for batch_index, (train_x, train_y) in enumerate(train_loader):

                 # Carrega os dados no dispositivo (GPU)
                train_x = train_x.to(device, non_blocking=True)
                train_y = train_y.to(device, non_blocking=True).unsqueeze(1)
                
                #Roda o foward com autocast para aproveitar do boost fp16 dos tensorcores
                with torch.autocast(device_type="cuda", dtype=torch.float16, enabled=use_amp):
                   
                    train_output = self(train_x)
                    train_loss = cost_function(train_output, train_y)

        
                # faz update da loss acumulada
                acum_train_loss += train_loss.item()
                
                # Backward e update
                # Zera o gradiente para evitar BO (set to none = + desempenho)
                optimizer.zero_grad(set_to_none=True)    

                #aplica escala na loss e aplica o backward
                scaler.scale(train_loss).backward()

                #se tiver algum NaN ou inf, optimizer.step() não é executado
                scaler.step(optimizer)

                #atualiza o scaler para a proxima iteração
                scaler.update()
    
            # Validação
            self.eval()
            
            # Não precisa calcular gradiente para a validação
            with torch.no_grad():  
                for batch_index, (val_x, val_y) in enumerate(val_loader):

                    val_x = val_x.to(device, non_blocking=True)
                    val_y = val_y.to(device, non_blocking=True).unsqueeze(1)

                    with torch.autocast(device_type="cuda", dtype=torch.float16, enabled=use_amp):
                        val_output = self(val_x)
                        val_loss = cost_function(val_output, val_y)
                        
                    acum_val_loss += val_loss.item()
    
            # Calcula as metricas para a epoca
            epoch_train_loss = acum_train_loss / len(train_loader)
            epoch_val_loss = acum_val_loss / len(val_loader)
            

            #atualiza o scheduller
            if scheduler is not None:
                #atualiza a lr
                lr_antiga = optimizer.param_groups[0]["lr"]
                scheduler.step(epoch_val_loss)
                lr_nova = optimizer.param_groups[0]["lr"]


            learning_rates.append(optimizer.param_groups[0]["lr"])
            
            # Salva a loss e a acuracia de treino e validação
            loss_history["train"].append(epoch_train_loss)
            loss_history["val"].append(epoch_val_loss)
    
            if verbose:
                print(f"Epoch {epoch + 1}/{num_epochs} > Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}")

        return loss_history, learning_rates

# %% [markdown]
# ### Treinamento

# %%
data =  datagen(qtd_amostras = 5000)

# Faz o split do dataset em treino e validação
split_index = int(len(data) * 0.9)
train_data = data[:split_index]
val_data = data[split_index:]

#cria os objetos do tipo dataset
step_ahead = 64
train_ds = TSDataset(train_data, step_ahead)
val_ds = TSDataset(val_data, step_ahead)

#cria os dataloaders
train_loader = DataLoader(train_ds, batch_size=256, pin_memory=True, shuffle=False, num_workers=4)
val_loader = DataLoader(val_ds, batch_size=64, pin_memory=True, shuffle=False, num_workers=2)

# %%
import torch.optim.lr_scheduler as lr_scheduler

#verifica se tem gpu disponível e configura automaticamente
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

#cria o modelo e o atribui para o melhor dispositivo encontrado

#modelo baseado no resnet
modelo = MeuModelo(step_ahead).to(device, non_blocking=True)

#configuração do otimizador: melhor 5e-4 (val loss 0.0022)
learning_rate = 5e-4

# melhor 0.0005 (val loss 0.0022)
decay = 0.0005

#configuração epocas
epochs = 200

#optimizer = torch.optim.Adam(modelo.parameters(), lr=learning_rate, weight_decay = decay, fused=True)
optimizer = torch.optim.AdamW(modelo.parameters(), lr=learning_rate, weight_decay = decay, fused=True)

#scheduler = None
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.618, patience=30, threshold=1e-2, threshold_mode='abs')
#scheduler = lr_scheduler.OneCycleLR(optimizer, max_lr=learning_rate, div_factor= 30, steps_per_epoch=1, epochs=epochs)
#scheduler = lr_scheduler.CyclicLR(optimizer, base_lr=learning_rate, max_lr = 0.01, step_size_up = 15, step_size_down=25, mode="triangular2")
#scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2, eta_min=0.0001)
#scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=1e-6)
#scheduler = lr_scheduler.LinearLR(optimizer, start_factor=1, end_factor=0.01, total_iters=epochs)

#função de loss
cost = nn.MSELoss()

# %%
summary(modelo, input_size=(step_ahead,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 64]           4,160
#        BatchNorm1d-2                   [-1, 64]             128
#          LeakyReLU-3                   [-1, 64]               0
#            Dropout-4                   [-1, 64]               0
#             Linear-5                   [-1, 64]           4,160
#        BatchNorm1d-6                   [-1, 64]             128
#          LeakyReLU-7                   [-1, 64]               0
#            Dropout-8                   [-1, 64]               0
#             Linear-9                   [-1, 32]           2,080
#       BatchNorm1d-10                   [-1, 32]              64
#         LeakyReLU-11                   [-1, 32]               0
#           Dropout-12                   [-1, 32]               0
#            Linear-13                    [-1, 1]              33
# ================================================================
# Total params: 10,753
# Trainable params: 10,753
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.05
# ----------------------------------------------------------------

# %%
hist, learning_rates = modelo.treinar(train_loader, val_loader,  epochs, cost, optimizer, scheduler=scheduler, verbose=True)
# Out:
# Epoch 1/200 > Train Loss: 0.6528, Val Loss: 0.1210
# Epoch 2/200 > Train Loss: 0.2365, Val Loss: 0.0783
# Epoch 3/200 > Train Loss: 0.1711, Val Loss: 0.0642
# Epoch 4/200 > Train Loss: 0.1377, Val Loss: 0.0492
# Epoch 5/200 > Train Loss: 0.1192, Val Loss: 0.0404
# Epoch 6/200 > Train Loss: 0.1063, Val Loss: 0.0335
# Epoch 7/200 > Train Loss: 0.0979, Val Loss: 0.0282
# Epoch 8/200 > Train Loss: 0.0873, Val Loss: 0.0245
# Epoch 9/200 > Train Loss: 0.0780, Val Loss: 0.0228
# Epoch 10/200 > Train Loss: 0.0707, Val Loss: 0.0201
# Epoch 11/200 > Train Loss: 0.0671, Val Loss: 0.0184
# Epoch 12/200 > Train Loss: 0.0642, Val Loss: 0.0167
# Epoch 13/200 > Train Loss: 0.0615, Val Loss: 0.0161
# Epoch 14/200 > Train Loss: 0.0565, Val Loss: 0.0149
# Epoch 15/200 > Train Loss: 0.0555, Val Loss: 0.0136
# Epoch 16/200 > Train Loss: 0.0503, Val Loss: 0.0129
# Epoch 17/200 > Train Loss: 0.0514, Val Loss: 0.0123
# Epoch 18/200 > Train Loss: 0.0493, Val Loss: 0.0120
# Epoch 19/200 > Train Loss: 0.0453, Val Loss: 0.0115
# Epoch 20/200 > Train Loss: 0.0456, Val Loss: 0.0110
# Epoch 21/200 > Train Loss: 0.0454, Val Loss: 0.0107
# Epoch 22/200 > Train Loss: 0.0424, Val Loss: 0.0102
# Epoch 23/200 > Train Loss: 0.0394, Val Loss: 0.0101
# Epoch 24/200 > Train Loss: 0.0404, Val Loss: 0.0101
# Epoch 25/200 > Train Loss: 0.0372, Val Loss: 0.0091
# Epoch 26/200 > Train Loss: 0.0363, Val Loss: 0.0095
# Epoch 27/200 > Train Loss: 0.0357, Val Loss: 0.0089
# Epoch 28/200 > Train Loss: 0.0327, Val Loss: 0.0086
# Epoch 29/200 > Train Loss: 0.0369, Val Loss: 0.0088
# Epoch 30/200 > Train Loss: 0.0332, Val Loss: 0.0082
# Epoch 31/200 > Train Loss: 0.0332, Val Loss: 0.0078
# Epoch 32/200 > Train Loss: 0.0341, Val Loss: 0.0075
# Epoch 33/200 > Train Loss: 0.0290, Val Loss: 0.0074
# Epoch 34/200 > Train Loss: 0.0309, Val Loss: 0.0074
# Epoch 35/200 > Train Loss: 0.0313, Val Loss: 0.0073
# Epoch 36/200 > Train Loss: 0.0287, Val Loss: 0.0074
# Epoch 37/200 > Train Loss: 0.0275, Val Loss: 0.0070
# Epoch 38/200 > Train Loss: 0.0279, Val Loss: 0.0072
# Epoch 39/200 > Train Loss: 0.0265, Val Loss: 0.0069
# Epoch 40/200 > Train Loss: 0.0284, Val Loss: 0.0066
# Epoch 41/200 > Train Loss: 0.0270, Val Loss: 0.0068
# Epoch 42/200 > Train Loss: 0.0253, Val Loss: 0.0068
# Epoch 43/200 > Train Loss: 0.0253, Val Loss: 0.0066
# Epoch 44/200 > Train Loss: 0.0255, Val Loss: 0.0061
# Epoch 45/200 > Train Loss: 0.0264, Val Loss: 0.0061
# Epoch 46/200 > Train Loss: 0.0268, Val Loss: 0.0062
# Epoch 47/200 > Train Loss: 0.0228, Val Loss: 0.0062
# Epoch 48/200 > Train Loss: 0.0246, Val Loss: 0.0061
# Epoch 49/200 > Train Loss: 0.0233, Val Loss: 0.0062
# Epoch 50/200 > Train Loss: 0.0221, Val Loss: 0.0062
# Epoch 51/200 > Train Loss: 0.0222, Val Loss: 0.0060
# Epoch 52/200 > Train Loss: 0.0222, Val Loss: 0.0057
# Epoch 53/200 > Train Loss: 0.0209, Val Loss: 0.0059
# Epoch 54/200 > Train Loss: 0.0219, Val Loss: 0.0057
# Epoch 55/200 > Train Loss: 0.0226, Val Loss: 0.0055
# Epoch 56/200 > Train Loss: 0.0214, Val Loss: 0.0056
# Epoch 57/200 > Train Loss: 0.0219, Val Loss: 0.0056
# Epoch 58/200 > Train Loss: 0.0208, Val Loss: 0.0057
# Epoch 59/200 > Train Loss: 0.0215, Val Loss: 0.0054
# Epoch 60/200 > Train Loss: 0.0207, Val Loss: 0.0058
# Epoch 61/200 > Train Loss: 0.0215, Val Loss: 0.0056
# Epoch 62/200 > Train Loss: 0.0201, Val Loss: 0.0052
# Epoch 63/200 > Train Loss: 0.0219, Val Loss: 0.0053
# Epoch 64/200 > Train Loss: 0.0182, Val Loss: 0.0052
# Epoch 65/200 > Train Loss: 0.0196, Val Loss: 0.0052
# Epoch 66/200 > Train Loss: 0.0192, Val Loss: 0.0051
# Epoch 67/200 > Train Loss: 0.0189, Val Loss: 0.0051
# Epoch 68/200 > Train Loss: 0.0191, Val Loss: 0.0050
# Epoch 69/200 > Train Loss: 0.0188, Val Loss: 0.0049
# Epoch 70/200 > Train Loss: 0.0190, Val Loss: 0.0049
# Epoch 71/200 > Train Loss: 0.0192, Val Loss: 0.0050
# Epoch 72/200 > Train Loss: 0.0193, Val Loss: 0.0049
# Epoch 73/200 > Train Loss: 0.0181, Val Loss: 0.0047
# Epoch 74/200 > Train Loss: 0.0201, Val Loss: 0.0048
# Epoch 75/200 > Train Loss: 0.0178, Val Loss: 0.0047
# Epoch 76/200 > Train Loss: 0.0176, Val Loss: 0.0047
# Epoch 77/200 > Train Loss: 0.0179, Val Loss: 0.0045
# Epoch 78/200 > Train Loss: 0.0171, Val Loss: 0.0046
# Epoch 79/200 > Train Loss: 0.0185, Val Loss: 0.0045
# Epoch 80/200 > Train Loss: 0.0177, Val Loss: 0.0046
# Epoch 81/200 > Train Loss: 0.0177, Val Loss: 0.0047
# Epoch 82/200 > Train Loss: 0.0163, Val Loss: 0.0045
# Epoch 83/200 > Train Loss: 0.0162, Val Loss: 0.0045
# Epoch 84/200 > Train Loss: 0.0177, Val Loss: 0.0045
# Epoch 85/200 > Train Loss: 0.0188, Val Loss: 0.0043
# Epoch 86/200 > Train Loss: 0.0167, Val Loss: 0.0042
# Epoch 87/200 > Train Loss: 0.0170, Val Loss: 0.0044
# Epoch 88/200 > Train Loss: 0.0166, Val Loss: 0.0045
# Epoch 89/200 > Train Loss: 0.0161, Val Loss: 0.0046
# Epoch 90/200 > Train Loss: 0.0173, Val Loss: 0.0044
# Epoch 91/200 > Train Loss: 0.0170, Val Loss: 0.0045
# Epoch 92/200 > Train Loss: 0.0157, Val Loss: 0.0044
# Epoch 93/200 > Train Loss: 0.0174, Val Loss: 0.0044
# Epoch 94/200 > Train Loss: 0.0173, Val Loss: 0.0043
# Epoch 95/200 > Train Loss: 0.0164, Val Loss: 0.0042
# Epoch 96/200 > Train Loss: 0.0160, Val Loss: 0.0044
# Epoch 97/200 > Train Loss: 0.0160, Val Loss: 0.0040
# Epoch 98/200 > Train Loss: 0.0157, Val Loss: 0.0041
# Epoch 99/200 > Train Loss: 0.0155, Val Loss: 0.0043
# Epoch 100/200 > Train Loss: 0.0150, Val Loss: 0.0041
# Epoch 101/200 > Train Loss: 0.0142, Val Loss: 0.0040
# Epoch 102/200 > Train Loss: 0.0149, Val Loss: 0.0042
# Epoch 103/200 > Train Loss: 0.0155, Val Loss: 0.0041
# Epoch 104/200 > Train Loss: 0.0164, Val Loss: 0.0041
# Epoch 105/200 > Train Loss: 0.0148, Val Loss: 0.0041
# Epoch 106/200 > Train Loss: 0.0144, Val Loss: 0.0040
# Epoch 107/200 > Train Loss: 0.0143, Val Loss: 0.0039
# Epoch 108/200 > Train Loss: 0.0138, Val Loss: 0.0041
# Epoch 109/200 > Train Loss: 0.0154, Val Loss: 0.0040
# Epoch 110/200 > Train Loss: 0.0149, Val Loss: 0.0041
# Epoch 111/200 > Train Loss: 0.0155, Val Loss: 0.0037
# Epoch 112/200 > Train Loss: 0.0141, Val Loss: 0.0038
# Epoch 113/200 > Train Loss: 0.0163, Val Loss: 0.0039
# Epoch 114/200 > Train Loss: 0.0138, Val Loss: 0.0038
# Epoch 115/200 > Train Loss: 0.0142, Val Loss: 0.0037
# Epoch 116/200 > Train Loss: 0.0147, Val Loss: 0.0038
# Epoch 117/200 > Train Loss: 0.0143, Val Loss: 0.0039
# Epoch 118/200 > Train Loss: 0.0140, Val Loss: 0.0038
# Epoch 119/200 > Train Loss: 0.0147, Val Loss: 0.0038
# Epoch 120/200 > Train Loss: 0.0143, Val Loss: 0.0038
# Epoch 121/200 > Train Loss: 0.0141, Val Loss: 0.0037
# Epoch 122/200 > Train Loss: 0.0137, Val Loss: 0.0037
# Epoch 123/200 > Train Loss: 0.0138, Val Loss: 0.0038
# Epoch 124/200 > Train Loss: 0.0140, Val Loss: 0.0038
# Epoch 125/200 > Train Loss: 0.0131, Val Loss: 0.0037
# Epoch 126/200 > Train Loss: 0.0140, Val Loss: 0.0037
# Epoch 127/200 > Train Loss: 0.0133, Val Loss: 0.0036
# Epoch 128/200 > Train Loss: 0.0145, Val Loss: 0.0037
# Epoch 129/200 > Train Loss: 0.0137, Val Loss: 0.0036
# Epoch 130/200 > Train Loss: 0.0134, Val Loss: 0.0036
# Epoch 131/200 > Train Loss: 0.0136, Val Loss: 0.0035
# Epoch 132/200 > Train Loss: 0.0140, Val Loss: 0.0038
# Epoch 133/200 > Train Loss: 0.0148, Val Loss: 0.0036
# Epoch 134/200 > Train Loss: 0.0122, Val Loss: 0.0036
# Epoch 135/200 > Train Loss: 0.0133, Val Loss: 0.0037
# Epoch 136/200 > Train Loss: 0.0135, Val Loss: 0.0037
# Epoch 137/200 > Train Loss: 0.0129, Val Loss: 0.0036
# Epoch 138/200 > Train Loss: 0.0137, Val Loss: 0.0037
# Epoch 139/200 > Train Loss: 0.0138, Val Loss: 0.0035
# Epoch 140/200 > Train Loss: 0.0142, Val Loss: 0.0035
# Epoch 141/200 > Train Loss: 0.0131, Val Loss: 0.0034
# Epoch 142/200 > Train Loss: 0.0134, Val Loss: 0.0034
# Epoch 143/200 > Train Loss: 0.0139, Val Loss: 0.0034
# Epoch 144/200 > Train Loss: 0.0137, Val Loss: 0.0035
# Epoch 145/200 > Train Loss: 0.0131, Val Loss: 0.0035
# Epoch 146/200 > Train Loss: 0.0132, Val Loss: 0.0034
# Epoch 147/200 > Train Loss: 0.0130, Val Loss: 0.0035
# Epoch 148/200 > Train Loss: 0.0131, Val Loss: 0.0035
# Epoch 149/200 > Train Loss: 0.0127, Val Loss: 0.0035
# Epoch 150/200 > Train Loss: 0.0126, Val Loss: 0.0034
# Epoch 151/200 > Train Loss: 0.0127, Val Loss: 0.0034
# Epoch 152/200 > Train Loss: 0.0120, Val Loss: 0.0034
# Epoch 153/200 > Train Loss: 0.0127, Val Loss: 0.0034
# Epoch 154/200 > Train Loss: 0.0127, Val Loss: 0.0035
# Epoch 155/200 > Train Loss: 0.0130, Val Loss: 0.0034
# Epoch 156/200 > Train Loss: 0.0136, Val Loss: 0.0034
# Epoch 157/200 > Train Loss: 0.0132, Val Loss: 0.0034
# Epoch 158/200 > Train Loss: 0.0123, Val Loss: 0.0034
# Epoch 159/200 > Train Loss: 0.0117, Val Loss: 0.0034
# Epoch 160/200 > Train Loss: 0.0125, Val Loss: 0.0032
# Epoch 161/200 > Train Loss: 0.0113, Val Loss: 0.0033
# Epoch 162/200 > Train Loss: 0.0123, Val Loss: 0.0034
# Epoch 163/200 > Train Loss: 0.0132, Val Loss: 0.0034
# Epoch 164/200 > Train Loss: 0.0132, Val Loss: 0.0033
# Epoch 165/200 > Train Loss: 0.0130, Val Loss: 0.0032
# Epoch 166/200 > Train Loss: 0.0127, Val Loss: 0.0033
# Epoch 167/200 > Train Loss: 0.0123, Val Loss: 0.0033
# Epoch 168/200 > Train Loss: 0.0130, Val Loss: 0.0033
# Epoch 169/200 > Train Loss: 0.0128, Val Loss: 0.0033
# Epoch 170/200 > Train Loss: 0.0130, Val Loss: 0.0032
# Epoch 171/200 > Train Loss: 0.0133, Val Loss: 0.0033
# Epoch 172/200 > Train Loss: 0.0111, Val Loss: 0.0033
# Epoch 173/200 > Train Loss: 0.0132, Val Loss: 0.0034
# Epoch 174/200 > Train Loss: 0.0117, Val Loss: 0.0033
# Epoch 175/200 > Train Loss: 0.0124, Val Loss: 0.0032
# Epoch 176/200 > Train Loss: 0.0126, Val Loss: 0.0033
# Epoch 177/200 > Train Loss: 0.0124, Val Loss: 0.0033
# Epoch 178/200 > Train Loss: 0.0119, Val Loss: 0.0032
# Epoch 179/200 > Train Loss: 0.0124, Val Loss: 0.0033
# Epoch 180/200 > Train Loss: 0.0126, Val Loss: 0.0033
# Epoch 181/200 > Train Loss: 0.0129, Val Loss: 0.0033
# Epoch 182/200 > Train Loss: 0.0121, Val Loss: 0.0032
# Epoch 183/200 > Train Loss: 0.0119, Val Loss: 0.0032
# Epoch 184/200 > Train Loss: 0.0119, Val Loss: 0.0033
# Epoch 185/200 > Train Loss: 0.0117, Val Loss: 0.0032
# Epoch 186/200 > Train Loss: 0.0115, Val Loss: 0.0032
# Epoch 187/200 > Train Loss: 0.0120, Val Loss: 0.0033
# Epoch 188/200 > Train Loss: 0.0127, Val Loss: 0.0034
# Epoch 189/200 > Train Loss: 0.0117, Val Loss: 0.0033
# Epoch 190/200 > Train Loss: 0.0113, Val Loss: 0.0032
# Epoch 191/200 > Train Loss: 0.0121, Val Loss: 0.0032
# Epoch 192/200 > Train Loss: 0.0126, Val Loss: 0.0032
# Epoch 193/200 > Train Loss: 0.0114, Val Loss: 0.0033
# Epoch 194/200 > Train Loss: 0.0125, Val Loss: 0.0032
# Epoch 195/200 > Train Loss: 0.0117, Val Loss: 0.0032
# Epoch 196/200 > Train Loss: 0.0115, Val Loss: 0.0031
# Epoch 197/200 > Train Loss: 0.0113, Val Loss: 0.0032
# Epoch 198/200 > Train Loss: 0.0120, Val Loss: 0.0031
# Epoch 199/200 > Train Loss: 0.0115, Val Loss: 0.0031
# Epoch 200/200 > Train Loss: 0.0123, Val Loss: 0.0031

# %%
fig, ax1 = plt.subplots()
ax1.plot(hist["train"], label="treino")
ax1.plot(hist["val"], label="val")

ax1.set_xlabel("Epoch") 
ax1.set_ylabel("Loss MSE") 
ax1.legend(loc='upper right')

ax2 = ax1.twinx()
ax2.plot(learning_rates, 'g-', label="lr")
ax2.legend(loc='center right')

plt.title("Curvas de Loss") 
plt.show()

# %%
#torch.save(modelo, "/home/lucas/mestrado/RNP-Trabalho2/modelo1")

# %%
m = torch.load("/home/lucas/mestrado/RNP-Trabalho2/modelo1")
m = m.to(device, non_blocking=True)

# %%
def print_recursive(modelo, dados, instante, step_ahead):
    # Dispositivo para o processamento
    device = next(modelo.parameters()).device

    #ativa o autotuner do cuDNN = + performace
    torch.backends.cudnn.benchmark = True

    #otimização gpu
    use_amp = True
    
    len_dados = len(dados)
    history = torch.tensor(dados[:instante], dtype=torch.float32)

    # Não precisa calcular gradiente 
    modelo.eval()
    with torch.no_grad():  
        for _ in range(instante, len_dados):

            # pega os ultimos dados como entrada
            x = history[-step_ahead:]
            x = x.to(device, non_blocking=True).unsqueeze(0)

            with torch.autocast(device_type="cuda", dtype=torch.float16, enabled=use_amp):
                y = modelo(x)

            #concatena a nova predição
            history = torch.cat((history, y.cpu().flatten()), dim=0) 

    plt.figure(figsize=(12, 6))
    plt.plot(dados, color="g", label="original")
    plt.plot(range(instante, len_dados), history[instante:], color="b", label="predito")
    plt.axvline(x=instante, color='r', linestyle='--')
    
    plt.xlabel("tempo") 
    plt.ylabel("Valores") 
    plt.title("Predição recursiva") 
    plt.legend()
    plt.show()

    #retorna os dados original e predito a partir do instante de predição
    return np.array(dados[instante:]), history[instante:].numpy()

# %%
data2 =  datagen(qtd_amostras = 600)
split = 350
orig, pred = print_recursive(m, data2, split, step_ahead)

# %% [markdown]
# ## Teste de hipótese (Teste de Kolmogorov)

# %% [markdown]
# Hipótese nula: Não existe diferença entre a função predita pelo modelo e a saída real.</br>
# Hipótese alternativa: Existe uma diferença entre a função predita pelo modelo e saída real.

# %%
from scipy import stats
stats.ks_2samp(orig, pred)
# Out:
# KstestResult(statistic=np.float64(0.048), pvalue=np.float64(0.9363359992328345), statistic_location=np.float64(0.2122601462624083), statistic_sign=np.int8(1))

# %% [markdown]
# #### Interpretação

# %% [markdown]
# Assumindo um limiar de 5%, temos que como pvalue > 0.05, falhamos em rejeitar a hipótese nula. O parâmetro statistics nos diz que a diferença absoluta máxima é de 0.048. Conclusão: Os dados são representados pela mesma distribuição

# %% [markdown]
# ## Plot quartil-quartil (Q-Q Plot)

# %%
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot_2samples
qqplot_2samples(orig, pred, line="45")
plt.show()

# %% [markdown]
# #### Interpretação

# %% [markdown]
# Pelo gráfico, como segue a linha dos 45º, é possível inferir que as predições feitas pelo modelo pertencem à mesma distribuição dos dados originais, bem como é não é possível perceber a presença de outliers significativos. Portanto é possível inferir que temos um bom modelo

# %% [markdown]
# ## Autocorrelação

# %%
from statsmodels.tsa.stattools import acf
ac_orig = acf(orig, fft=True)
ac_pred = acf(pred, fft=True)

# %%
plt.figure()
plt.stem(ac_orig, linefmt = "b", label="original")
plt.stem(ac_pred, linefmt = "r", label="predito")
plt.axhline(y=0, color='g', linestyle='--')

plt.xticks(np.arange(0, 26, 5))
plt.tick_params(axis='x', which='major', length=5)
plt.minorticks_on()
plt.tick_params(axis='x', which='minor', length=3, labelsize=0)

plt.title("Autocorrelação") 
plt.legend()
plt.show()

# %% [markdown]
# #### Interpretação

# %% [markdown]
# Pelo gráfico de correlação é possível notar que tanto os dados oriundos do modelo quanto os dados originais possuem curvas de correlação bastante similares, o que significa que a dependência temporal dos dados (tanto modelo e reais) respondem de forma similar quando tratados em relação a si mesmos

# %% [markdown]
# Além disso, temos autocorrelação positiva até proximo de um lag de 10, o que significa que a série tende a seguir a mesma direção. A partir disso, a autocorrelação é levemente negativa implicando que os sinais tendem a ter mudança de direção.

# %% [markdown]
# ## Erros quadraticos

# %%
def mse(pred, orig):
    return ((pred - orig)**2).mean(axis=0)

def eqmn(pred, orig, x_hat):
    u = np.array(orig).mean(axis=0)
    return mse(pred, orig)/(mse(x_hat, orig) + 1e-6)

# %%
#valor médio do processo
u = np.array(orig).mean(axis=0)
eqmn1 = eqmn(pred, orig, u)

#valor da amostra imediatamente anterior
x_hat_a = data2[split-1]
eqmn2 = eqmn(pred, orig, x_hat_a)

# %%
 print(f"EQMN1: {eqmn1:.4f} ,  EQMN2: {eqmn2:.4f}")
# Out:
# EQMN1: 0.1047 ,  EQMN2: 0.0222

# %% [markdown]
# #### Interpretação

# %% [markdown]
# Pelos dados, como EQMN1 << 1, é possível inferir que temos um preditor SUPERIOR a um preditor que apenas estime o valor futuro como o valor médio do processo

# %% [markdown]
# Também é possível inferir, como EQMN2 << 1, que temos um preditor SUPERIOR a um preditor que apenas estime o valor futuro como sendo igual ao valor imediatamente anterior ao processo.
